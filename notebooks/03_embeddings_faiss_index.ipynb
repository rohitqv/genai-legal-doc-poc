# %% [markdown]
# # Week 3: Embedding, RAG & LLM Pipeline (Part 1 - Embeddings & FAISS)
#
# This notebook handles:
# - Chunk embedding generation
# - FAISS index creation and storage
# - Vector search setup
