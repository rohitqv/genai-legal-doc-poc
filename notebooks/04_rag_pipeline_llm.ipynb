# %% [markdown]
# # Week 3: Embedding, RAG & LLM Pipeline (Part 2 - RAG & Extraction)
#
# This notebook handles:
# - RAG pipeline setup with LangChain
# - LLM integration for generation
# - Attribute extraction with ensemble validation
# - Storing results in Gold layer
